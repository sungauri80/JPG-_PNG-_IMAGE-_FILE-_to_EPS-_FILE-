# %%
import cv2

# %%
import numpy as np

# %%
from PIL import Image

# %%
image_01=Image.open("C:/Users/admin pc/Desktop/Lena-fig-1.png") # first open the PNG file.

# %%
image_01
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=392x266 at 0x2625FC3438>

# %%
image_02=image_01.convert(mode=None,matrix=None, dither=None, palette=0, colors=256)

# %%
image_03=Image.open("C:/Users/admin pc/Desktop/Fig_Lena_f_DSIHE.png") # open the PNG file.

# %%
image_03.save("C:/Users/admin pc/Desktop/Fig_Lena_f_DSIHE.eps") # convert the PNG file to EPS format by saving it to EPS format.

# %%
image_05=Image.open("C:/Users/admin pc/Desktop/hist_2_2.jpg") # OPen the JPG file.

# %%
image_05.save("C:/Users/admin pc/Desktop/hist_2_2.png") # convert the JPG file to PNG file by saving it in the form of PNG.

# %%
image_0666=Image.open("C:/Users/admin pc/Desktop/hist_2_2_2_2.jpg") # First open the jpg file.

# %%
image_0666
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x288 at 0x2625FA1D68>

# %%
image_0666.save("C:/Users/admin pc/Desktop/hist_2_2_2_2.png") # Then convert the jpg file to png file by saving it to png form.

# %%
image_06666=Image.open("C:/Users/admin pc/Desktop/hist_2_2_2_2.png") # First open the png file.

# %%
image_06666
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=432x288 at 0x2625FD5BA8>

# %%
image_06666.save("C:/Users/admin pc/Desktop/hist_2_2_2_2.eps") # Then convert the png file to eps format by saving the png file in the form of eps format at desired location.
